# %%
import pandas as pd
import numpy as np

df = pd.read_csv("customer_churn_dirty (1).csv")

# %%
columns = ['Customer_ID', 'Tenure_Months', 'Age', 'Gender', 'Contract_Type', 'Monthly_Charges', 'Total_Charges',
           'Payment_Method', 'Internet_Service', 'Has_Multiple_Lines', 'Streaming_TV', 'Churn', 'Reason_for_Churn']
df = pd.DataFrame(df, columns=columns)

# %%
churn_df = df.drop(columns=['Payment_Method', 'Customer_ID'])

# %%
churn_df['Gender'] = churn_df['Gender'].str.strip().str.lower()

churn_df['Gender'] = churn_df['Gender'].replace(['male', 'm'], 1)
churn_df['Gender'] = churn_df['Gender'].replace(['female', 'f'], 0)
churn_df['Gender'] = churn_df['Gender'].replace(['n/a', 'other'], 2)

# %%
# target1 = ['monthly', 'm', 'monthy']
# target2 = ['yearly', 'y']
# target3 = ['two-year', '2-year', 'two year']
churn_df['Contract_Type'] = churn_df['Contract_Type'].str.strip().str.lower()

churn_df['Contract_Type'] = churn_df['Contract_Type'].replace(
    ['monthly', 'm', 'monthy'], 1)
churn_df['Contract_Type'] = churn_df['Contract_Type'].replace([
                                                              'yearly', 'y'], 2)
churn_df['Contract_Type'] = churn_df['Contract_Type'].replace(
    ['two-year', '2-year', 'two year'], 3)

# %%
churn_df['Tenure_Months'] = churn_df['Tenure_Months'].abs()

# %%
churn_df['Monthly_Charges'] = pd.to_numeric(
    churn_df['Monthly_Charges'], errors='coerce')
churn_df['Monthly_Charges'] = churn_df['Monthly_Charges'].replace(
    r'[^\d.]', '', regex=True)

# %%
churn_df['Age'] = pd.to_numeric(churn_df['Age'], errors='coerce')

median_age = churn_df['Age'].median()
churn_df['Age'] = churn_df['Age'].fillna(median_age)
churn_df['Age'] = churn_df['Age'].astype(int)

# %%
churn_df['Total_Charges'] = pd.to_numeric(
    churn_df['Total_Charges'], errors='coerce')
missing_total_value = churn_df['Tenure_Months'] * churn_df['Monthly_Charges']

churn_df['Total_Charges'] = churn_df['Total_Charges'].fillna(
    missing_total_value)
churn_df['Total_Charges'] = churn_df['Total_Charges'].abs()

# %%
churn_df.head(60)
# Out:
#     Tenure_Months  Age Gender Contract_Type  Monthly_Charges  Total_Charges  \
# 0            19.0   46      0             1            24.20         457.73
# 1            49.0   54      0             1            50.16        2469.71
# 2            19.0   66    NaN             1            89.79        1727.28
# 3            41.0   58      0             2            95.87        3930.67
# 4             6.0   22      1             1            21.78         143.25
# 5            45.0   53      0             2            23.49        1057.05
# 6            35.0   46      1             3            49.53        1726.09
# 7             7.0   40      1             1            82.67         624.40
# 8            21.0   52      0             2            47.06         988.26
# 9            21.0   42      0             1            90.45        1899.45
# 10           11.0   43      1             1            74.32         783.80
# 11            3.0   25      1             1            68.16         193.51
# 12           20.0   40      0             1            46.57         931.40
# 13           53.0   31      1             1            76.27        4033.81
# 14           32.0   45      0             1            87.01        2773.44
# 15           72.0   43      0             1            78.33        5632.88
# 16           36.0   51      1             2            80.40        2885.33
# 17            1.0   67      0             1            50.93          50.93
# 18           57.0   24      1             1            77.13        4391.92
# 19           17.0   43      1             1            18.00         321.60
# 20            7.0   25      1             2           102.22         728.78
# 21            4.0   41      1             1            49.70         179.02
# 22            6.0   18      0             3            80.79         484.74
# 23           53.0   24      0             3            72.15        3841.40
# 24           41.0   63      0             3            47.35        1943.89
# 25           15.0   42      1             1            73.90        1057.62
# 26           20.0   40      1             1            86.22         944.33
# 27            2.0   72      1             1            57.70          83.72
# 28           41.0   36  other             2            49.15        2015.15
# 29           20.0   44      0             1            66.95        1340.61
# 30           18.0   47      1             1            86.63        1555.51
# 31           22.0   18      1             1            57.87        1262.16
# 32           38.0   61      1             3              NaN            NaN
# 33           11.0   54      0             3            48.40         559.67
# 34           18.0   41      0             1            68.08        1241.93
# 35           46.0   38      0             2            60.92        2802.32
# 36            3.0   33      1             1            79.93         124.92
# 37            1.0   63      1             1            64.36          63.04
# 38           38.0   42      1             2            78.64        2988.32
# 39           19.0   64      1             1            93.96        1808.75
# 40           72.0   26      0             3            86.28        6237.55
# 41           15.0   37      1             1            52.51         769.09
# 42            5.0   45      1             2            68.71          58.58
# 43           60.0   25      1             3            52.38        3122.12
# 44           14.0   77      1             3            93.19        1288.86
# 45           52.0   44      1             1            68.26        3543.24
# 46            0.0   62      1             1            74.50          71.48
# 47           33.0   52      0             1            82.44        2708.17
# 48           45.0   50      1             2            84.47        3818.32
# 49            2.0   54      0             1            27.34          78.64
# 50           18.0   24      0             1            40.31         716.37
# 51           46.0   44      1             3            25.25        1175.34
# 52            2.0   51      1             1            86.85         209.46
# 53           11.0   54      0             1            80.81         891.33
# 54            4.0   19      1             1            18.00          77.77
# 55            1.0   68      1             1            80.08          80.08
# 56           29.0   44      0             3            61.07        1767.77
# 57           35.0   70      0             3            78.00        2742.83
# 58           16.0   57      0             1            69.61        1113.02
# 59           15.0   22      1             1            80.05        1198.65
#
#    Internet_Service Has_Multiple_Lines Streaming_TV Churn Reason_for_Churn
# 0                No                 No           No   Yes            Other
# 1               NaN                 no           No    No            Other
# 2       Fiber Optic                Yes           No   Yes            Price
# 3       Fiber Optic                Yes          Yes    No              NaN
# 4                No                 No           No   Yes            Price
# 5                No                 No           No    No              NaN
# 6               DSL                Yes           No    No              NaN
# 7       Fiber Optic                Yes           No   Yes            Price
# 8               DSL                 No          Yes   Yes       Competitor
# 9       Fiber Optic                Yes          Yes   Yes            Price
# 10      Fiber Optic                  N          Yes     Y            Price
# 11      Fiber Optic                 No           No   Yes     Poor Service
# 12              DSL                 No           No    No              NaN
# 13      Fiber Optic                 No          Yes    No              NaN
# 14      Fiber Optic                Yes          Yes   Yes            Price
# 15      Fiber Optic                 No           No   Yes            Other
# 16              DSL                Yes          Yes    No              NaN
# 17              DSL                NaN           No    No              NaN
# 18              DSL                Yes          Yes    No              NaN
# 19               No                 No           No    No              NaN
# 20      Fiber Optic                Yes          Yes   Yes    poor service
# 21              DSL                 No           No    No              NaN
# 22      Fiber Optic                 No          Yes   Yes            Price
# 23            fiber                Yes          Yes    No              NaN
# 24              DSL                 No           No    No              NaN
# 25      Fiber Optic                  N          Yes    No              NaN
# 26      Fiber Optic                 No          Yes   Yes            Price
# 27              DSL                Yes           No   Yes            Price
# 28              DSL                  1          Yes    No              NaN
# 29      Fiber Optic                 No          Yes    No              NaN
# 30      Fiber Optic                Yes           No   Yes     Poor Service
# 31      Fiber Optic                 No           No    No              NaN
# 32      Fiber Optic                Yes          Yes    No              NaN
# 33              DSL                 No           No    No              NaN
# 34              DSL                Yes          Yes   Yes            Price
# 35              dsl                 No          Yes    No              NaN
# 36      Fiber Optic                Yes           No   Yes              NaN
# 37              DSL                 No          Yes   Yes            Other
# 38      Fiber Optic                Yes           No   Yes              NaN
# 39      Fiber Optic                Yes          Yes   Yes            Price
# 40      Fiber Optic                Yes          Yes    No              NaN
# 41             none                 No           No    No            Other
# 42      Fiber Optic                 No           No    No              NaN
# 43              DSL                 No          Yes    No              NaN
# 44      Fiber Optic                Yes          Yes    No              NaN
# 45      Fiber Optic                 No           No    No       competitor
# 46      Fiber Optic                 No          Yes   Yes              NaN
# 47      Fiber Optic                 No          Yes   Yes    poor service
# 48      Fiber Optic                 No           No    No              NaN
# 49               No                 No           No    No              NaN
# 50               No                Yes           No    No              NaN
# 51               No                 No           No   Yes            Price
# 52      Fiber Optic                Yes           No   Yes       Competitor
# 53      Fiber Optic                Yes           No   Yes            Other
# 54               No                 No           No   Yes     Poor Service
# 55      Fiber Optic                 No          Yes   Yes            Other
# 56              NaN                 No           No    No              NaN
# 57      Fiber Optic                Yes           No    No              NaN
# 58      Fiber Optic                 No           No    No              NaN
# 59      Fiber Optic                 No           No    No              NaN

# %%
churn_df['Age'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 10100 entries, 0 to 10099
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 9661 non-null   str
# dtypes: str(1)
# memory usage: 79.0 KB
